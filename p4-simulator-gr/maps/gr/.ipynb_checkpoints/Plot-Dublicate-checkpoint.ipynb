# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("dpp_policy_hyperparam.csv") 
data = data[data['map']=='scatter']
data = data[data['start']=="(5, 10)"]
data.loc[(data.agent == 'agent_drl_honest'),'agent']='Truthful'
data.loc[(data.agent == 'agent_drl_mid'),'agent']='Indiff'
data.loc[(data.agent == 'agent_drl_mid_optimised'),'agent']='Indiff-pruned'
data.loc[(data.agent == 'agent_drl_policy'),'agent']='Policy'
data.loc[(data.agent == 'agent_drl_org'),'agent']='Ambiguity'
data.loc[(data.agent == 'agent_ds4'),'agent']='πd4'

# %%
data.head()
# Out:
#          map                           agent    start  optcost  density  \
# 290  scatter  agent_drl_policy-lamda:0.1-w:2  (5, 10)   43.624       10
# 291  scatter  agent_drl_policy-lamda:0.1-w:2  (5, 10)   43.624       20
# 292  scatter  agent_drl_policy-lamda:0.1-w:2  (5, 10)   43.624       30
# 293  scatter  agent_drl_policy-lamda:0.1-w:2  (5, 10)   43.624       40
# 294  scatter  agent_drl_policy-lamda:0.1-w:2  (5, 10)   43.624       50
#
#     distribution  formula     goal0  costdif    cost  ...  cost.3  \
# 290            P        3  (42, 26)  797.172  48.592  ...     NaN
# 291            P        3  (42, 26)  791.516  48.592  ...     NaN
# 292            P        3  (42, 26)  785.860  48.592  ...     NaN
# 293            P        3  (42, 26)  780.204  48.592  ...     NaN
# 294            P        3  (42, 26)  776.204  48.592  ...     NaN
#
#     probability.3  goal4  costdif.4  cost.4 probability.4  goal5  costdif.5  \
# 290           NaN    NaN        NaN     NaN           NaN    NaN        NaN
# 291           NaN    NaN        NaN     NaN           NaN    NaN        NaN
# 292           NaN    NaN        NaN     NaN           NaN    NaN        NaN
# 293           NaN    NaN        NaN     NaN           NaN    NaN        NaN
# 294           NaN    NaN        NaN     NaN           NaN    NaN        NaN
#
#      cost.5  probability.5
# 290     NaN            NaN
# 291     NaN            NaN
# 292     NaN            NaN
# 293     NaN            NaN
# 294     NaN            NaN
#
# [5 rows x 31 columns]

# %%
avgdata = data.groupby(['agent', 'density'], as_index=False).mean()
avgdata = avgdata[avgdata['density']!=100] #exclude

# %%
avgdata.head()
# Out:
#          map     agent    start  optcost  density distribution  formula  \
# 290  scatter  Truthful  (5, 10)   43.624       10            P        3
# 291  scatter  Truthful  (5, 10)   43.624       20            P        3
# 292  scatter  Truthful  (5, 10)   43.624       30            P        3
# 293  scatter  Truthful  (5, 10)   43.624       40            P        3
# 294  scatter  Truthful  (5, 10)   43.624       50            P        3
#
#         goal0  costdif    cost  ...  goal3 costdif.3  cost.3  probability.3  \
# 290  (42, 26)  797.172  43.624  ...    NaN       NaN     NaN            NaN
# 291  (42, 26)  792.344  43.624  ...    NaN       NaN     NaN            NaN
# 292  (42, 26)  787.516  43.624  ...    NaN       NaN     NaN            NaN
# 293  (42, 26)  781.860  43.624  ...    NaN       NaN     NaN            NaN
# 294  (42, 26)  777.032  43.624  ...    NaN       NaN     NaN            NaN
#
#      goal4 costdif.4  cost.4  probability.4  goal5  costdif.5
# 290    NaN       NaN     NaN            NaN    NaN        NaN
# 291    NaN       NaN     NaN            NaN    NaN        NaN
# 292    NaN       NaN     NaN            NaN    NaN        NaN
# 293    NaN       NaN     NaN            NaN    NaN        NaN
# 294    NaN       NaN     NaN            NaN    NaN        NaN
#
# [5 rows x 29 columns]

# %%
plotdata = avgdata[['agent', 'density', 'probability','cost']]
plotdata.head()
# Out:
#         agent  density  probability    cost
# 290  Truthful       10         0.35  43.624
# 291  Truthful       20         0.40  43.624
# 292  Truthful       30         0.47  43.624
# 293  Truthful       40         0.50  43.624
# 294  Truthful       50         0.55  43.624

# %%
x = np.arange(10, 100, 10)
#print(x)
for agent in plotdata['agent'].unique():
    print(agent)
    #if agent in ["agent_drl_mid_optimized","Indiff","Indiff-pruned"]:
    y = np.asarray(plotdata[plotdata['agent']==agent]['probability'])
    plt.plot(x, y, label=agent)
    
plt.legend()
plt.xlabel('Density (%)')
plt.ylabel('Probability of true goal')

plt.grid(True)
plt.savefig('prob_per_density.jpg')
plt.show()
# Out:
# Truthful
# Policy
# Indiff
# Ambiguity
# agent_drl_mid_optimized
# πd4
# Indiff-pruned

# %%
costdata = plotdata[plotdata['density']==10][['agent','cost']]
costdata = costdata.sort_values(by=['cost'])

# %%
y = np.asarray(costdata['cost'])
n = (costdata[costdata['agent']=='Truthful']['cost']).iat[0]
y = np.true_divide(y, n)
print(y)
# Out:
# [1.         1.11388227 1.11388227 1.13286264 1.13286264 1.13286264
#  1.15184302 1.15184302 1.15184302 1.15184302 1.15184302 1.15184302
#  1.15184302 1.15184302 1.15184302 1.15184302 1.15184302]

# %%
x = np.asarray(costdata['agent'])
y = np.asarray(costdata['cost'])
oc = (costdata[costdata['agent']=='Truthful']['cost']).iat[0]
y = np.true_divide(y, oc)
costdata['costproprtion']=y
plt.plot(x, y, label=agent)
    
#plt.legend()
plt.xlabel('Model')
plt.ylabel('Cost in proportion to optimal')

plt.grid(True)
plt.savefig('cost_proportion.jpg')
plt.show()

# %%
costdata
# Out:
#                               agent     cost  costproprtion
# 0                          Truthful   43.624       1.000000
# 10   agent_drl_policy-lamda:0.1-w:2   48.592       1.113882
# 20   agent_drl_policy-lamda:0.1-w:3   48.592       1.113882
# 30   agent_drl_policy-lamda:0.1-w:4   49.420       1.132863
# 40   agent_drl_policy-lamda:0.1-w:5   49.420       1.132863
# 50   agent_drl_policy-lamda:0.1-w:6   49.420       1.132863
# 60   agent_drl_policy-lamda:0.3-w:2   49.420       1.132863
# 180  agent_drl_policy-lamda:1.5-w:4   50.248       1.151843
# 170  agent_drl_policy-lamda:1.5-w:3   50.248       1.151843
# 160  agent_drl_policy-lamda:1.5-w:2   50.248       1.151843
# 150    agent_drl_policy-lamda:1-w:6   50.248       1.151843
# 140    agent_drl_policy-lamda:1-w:5   50.248       1.151843
# 130    agent_drl_policy-lamda:1-w:4   50.248       1.151843
# 100  agent_drl_policy-lamda:0.3-w:6   50.248       1.151843
# 110    agent_drl_policy-lamda:1-w:2   50.248       1.151843
# 190  agent_drl_policy-lamda:1.5-w:5   50.248       1.151843
# 90   agent_drl_policy-lamda:0.3-w:5   50.248       1.151843
# 80   agent_drl_policy-lamda:0.3-w:4   50.248       1.151843
# 70   agent_drl_policy-lamda:0.3-w:3   50.248       1.151843
# 120    agent_drl_policy-lamda:1-w:3   50.248       1.151843
# 200  agent_drl_policy-lamda:1.5-w:6  112.286       2.573950

# %%
for agent in plotdata['agent'].unique():
    y = np.asarray(plotdata[plotdata['agent']==agent]['probability'])
    plt.bar(x, y, label=agent)
    
plt.legend()
plt.xlabel('Density (%)')
plt.ylabel('Probability of true goal')

plt.grid(True)
plt.show()
